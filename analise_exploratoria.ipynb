# %% [markdown]
# # Análise Exploratória — Copa do Mundo 2026
#
# Exploração dos dados históricos de partidas e do ranking FIFA, buscando entender como título, ranking e desempenho histórico se relacionam entre si. As tabelas produzidas aqui (`base_selecoes`, `desempenho_geral`) servem de referência para a engenharia de features feita em `modelo.ipynb`.

# %% [markdown]
# ## 1. Importação de bibliotecas e dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
decision = pd.read_csv('dados/partidas/decision.csv')
fresults = pd.read_csv('dados/partidas/fifa_results.csv')
penal = pd.read_csv('dados/partidas/penalty_kicks.csv')
rank = pd.read_csv('dados/ranking/fifa_ranking_2022-10-06.csv')
dados_copa = pd.read_csv('dados/copas/world_cup.csv')
match_results = pd.read_csv('dados/partidas/matches_1930_2022.csv')

# %% [markdown]
# ### Inspeção inicial das bases
# Visualização rápida das primeiras linhas de cada base, para conferir colunas e formatos antes de qualquer tratamento.

# %%
decision.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
fresults.head()
# Out:
#          date  home_team away_team       team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %%
penal.head()
# Out:
#          date    home_team     apponent_team       winner
# 0   8/22/1967        India            Taiwan       Taiwan
# 1  11/14/1971  South Korea  Vietnam Republic  South Korea
# 2    5/7/1972  South Korea              Iraq         Iraq
# 3   5/17/1972     Thailand       South Korea  South Korea
# 4   5/19/1972     Thailand          Cambodia     Thailand

# %%
rank.head()
# Out:
#         team team_code association  rank  previous_rank   points  \
# 0     Brazil       BRA    CONMEBOL     1              1  1841.30
# 1    Belgium       BEL        UEFA     2              2  1816.71
# 2  Argentina       ARG    CONMEBOL     3              3  1773.88
# 3     France       FRA        UEFA     4              4  1759.78
# 4    England       ENG        UEFA     5              5  1728.47
#
#    previous_points
# 0          1837.56
# 1          1821.92
# 2          1770.65
# 3          1764.85
# 4          1737.46

# %%
dados_copa.head()
# Out:
#    Year          Host  Teams   Champion    Runner-Up  \
# 0  2022         Qatar     32  Argentina       France
# 1  2018        Russia     32     France      Croatia
# 2  2014        Brazil     32    Germany    Argentina
# 3  2010  South Africa     32      Spain  Netherlands
# 4  2006       Germany     32      Italy       France
#
#                               TopScorrer  Attendance  AttendanceAvg  Matches
# 0                      Kylian Mbappé - 8     3404252          53191       64
# 1                         Harry Kane - 6     3031768          47371       64
# 2                    James Rodríguez - 6     3429873          53592       64
# 3  Wesley Sneijder, Thomas Müller... - 5     3178856          49670       64
# 4                     Miroslav Klose - 5     3352605          52384       64

# %%
match_results.head()
# Out:
#    home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0  Argentina    France           3      3.3           4.0           3
# 1    Croatia   Morocco           2      0.7           NaN           1
# 2     France   Morocco           2      2.0           NaN           0
# 3  Argentina   Croatia           3      2.3           NaN           0
# 4    Morocco  Portugal           1      1.4           NaN           0
#
#    away_xg  away_penalty      home_manager  home_captain  ...  \
# 0      2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 1      1.2           NaN      Zlatko Dalić   Luka Modrić  ...
# 2      0.9           NaN  Didier Deschamps   Hugo Lloris  ...
# 3      0.5           NaN    Lionel Scaloni  Lionel Messi  ...
# 4      0.9           NaN   Hoalid Regragui  Romain Saïss  ...
#
#   home_penalty_shootout_miss_long  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# ...

# %% [markdown]
# ## 2. Títulos e finais da Copa do Mundo
# A partir de `world_cup.csv`, contamos quantos títulos e quantas finais (título ou vice) cada seleção acumulou historicamente, criando a tabela `base_selecoes` que será enriquecida ao longo do notebook.

# %%
titulos = dados_copa['Champion'].value_counts().reset_index()
titulos.columns = ['team', 'titles']

# Contar finais (título ou vice)
finais = pd.concat([dados_copa['Champion'], dados_copa['Runner-Up']])
finais = finais.value_counts().reset_index()
finais.columns = ['team', 'finals']

# Unir as duas tabelas
base_selecoes = pd.merge(titulos, finais, on='team', how='outer').fillna(0)
# Corrigir nomes
base_selecoes['team'] = base_selecoes['team'].replace({'West Germany': 'Germany'})

# Reagrupar somando títulos e finais
base_selecoes = base_selecoes.groupby('team', as_index=False).sum()

# Ordenar por número de títulos
base_selecoes = base_selecoes.sort_values('titles', ascending=False).reset_index(drop=True)



# Garantir que os valores estão como inteiros
base_selecoes['titles'] = base_selecoes['titles'].astype(int)
base_selecoes['finals'] = base_selecoes['finals'].astype(int)

print(base_selecoes.sort_values('titles', ascending=False))
# Out:
#               team  titles  finals
# 0           Brazil       5       7
# 1            Italy       4       6
# 2          Germany       4       8
# 3        Argentina       3       6
# 4           France       2       4
# 5          Uruguay       2       2
# 6            Spain       1       1
# 7          England       1       1
# 8          Croatia       0       1
# 9   Czechoslovakia       0       2
# 10         Hungary       0       2
# 11     Netherlands       0       3
# 12          Sweden       0       1

# %% [markdown]
# ## 3. Ranking FIFA
# Adicionamos o ranking e a pontuação FIFA (snapshot de 2022) à base de seleções, padronizando os nomes dos times para permitir o merge.

# %%
rank['team'] = rank['team'].str.strip().str.lower()
base_selecoes['team'] = base_selecoes['team'].str.strip().str.lower()

# Selecionar apenas as colunas úteis do ranking
rank = rank[['team', 'rank', 'points']]

# Juntar com base_selecoes
base_selecoes = pd.merge(base_selecoes, rank, on='team', how='left')

# Visualizar
print(base_selecoes.sort_values('titles', ascending=False))
# Out:
#               team  titles  finals  rank   points
# 0           brazil       5       7   1.0  1841.30
# 1            italy       4       6   6.0  1726.14
# 2          germany       4       8  11.0  1650.21
# 3        argentina       3       6   3.0  1773.88
# 4           france       2       4   4.0  1759.78
# 5          uruguay       2       2  14.0  1638.71
# 6            spain       1       1   7.0  1715.22
# 7          england       1       1   5.0  1728.47
# 8          croatia       0       1  12.0  1645.64
# 9   czechoslovakia       0       2   NaN      NaN
# 10         hungary       0       2  36.0  1492.20
# 11     netherlands       0       3   8.0  1694.51
# 12          sweden       0       1  25.0  1553.33

# %% [markdown]
# ## 4. Desempenho histórico em partidas
# A partir de `matches_1930_2022.csv`, calculamos vitórias, empates, derrotas e gols marcados/sofridos de cada seleção, somando os jogos como mandante e visitante.

# %%
match_results['home_team'] = match_results['home_team'].str.lower().str.strip()
match_results['away_team'] = match_results['away_team'].str.lower().str.strip()

# Criar dataframes separados para casa e fora
home_stats = match_results[['home_team', 'home_score', 'away_score']].copy()
home_stats.columns = ['team', 'goals_for', 'goals_against']
home_stats['win'] = (home_stats['goals_for'] > home_stats['goals_against']).astype(int)
home_stats['draw'] = (home_stats['goals_for'] == home_stats['goals_against']).astype(int)
home_stats['loss'] = (home_stats['goals_for'] < home_stats['goals_against']).astype(int)

away_stats = match_results[['away_team', 'away_score', 'home_score']].copy()
away_stats.columns = ['team', 'goals_for', 'goals_against']
away_stats['win'] = (away_stats['goals_for'] > away_stats['goals_against']).astype(int)
away_stats['draw'] = (away_stats['goals_for'] == away_stats['goals_against']).astype(int)
away_stats['loss'] = (away_stats['goals_for'] < away_stats['goals_against']).astype(int)

# Concatenar estatísticas de casa e fora
all_stats = pd.concat([home_stats, away_stats])

# Agrupar por seleção
desempenho_geral = all_stats.groupby('team').agg({
    'goals_for': 'sum',
    'goals_against': 'sum',
    'win': 'sum',
    'draw': 'sum',
    'loss': 'sum'
}).reset_index()

# Calcular total de jogos
desempenho_geral['total_games'] = desempenho_geral['win'] + desempenho_geral['draw'] + desempenho_geral['loss']

print(desempenho_geral.sort_values('win', ascending=False).head())
# Out:
#          team  goals_for  goals_against  win  draw  loss  total_games
# 8      brazil        237            108   76    19    19          114
# 2   argentina        152            101   47    17    24           88
# 40      italy        128             77   45    21    17           83
# 28     france        136             85   39    14    20           73
# 29    germany        126             67   37     7    12           56

# %% [markdown]
# ### Consolidação da base de seleções
# Unimos títulos, ranking e desempenho histórico em `base_selecoes`, base para todas as análises seguintes.

# %%
# Juntar as bases
base_selecoes = pd.merge(base_selecoes, desempenho_geral, on='team', how='left')
base_selecoes.head()
# Out:
#         team  titles  finals  rank   points  goals_for  goals_against  win  \
# 0     brazil       5       7   1.0  1841.30        237            108   76
# 1      italy       4       6   6.0  1726.14        128             77   45
# 2    germany       4       8  11.0  1650.21        126             67   37
# 3  argentina       3       6   3.0  1773.88        152            101   47
# 4     france       2       4   4.0  1759.78        136             85   39
#
#    draw  loss  total_games
# 0    19    19          114
# 1    21    17           83
# 2     7    12           56
# 3    17    24           88
# 4    14    20           73

# %%
ranking = base_selecoes.sort_values(by='points', ascending=False)
print(ranking[['team', 'points', 'win', 'draw', 'loss']].head(10))
# Out:
#            team   points  win  draw  loss
# 0        brazil  1841.30   76    19    19
# 3     argentina  1773.88   47    17    24
# 4        france  1759.78   39    14    20
# 7       england  1728.47   32    22    20
# 1         italy  1726.14   45    21    17
# 6         spain  1715.22   31    17    19
# 11  netherlands  1694.51   30    14    11
# 2       germany  1650.21   37     7    12
# 8       croatia  1645.64   13     8     9
# 5       uruguay  1638.71   25    13    21

# %%
base_selecoes['points_per_game'] = base_selecoes['points'] / base_selecoes['total_games']
print(base_selecoes.sort_values('points_per_game', ascending=False)[['team', 'points_per_game']].head(10))
# Out:
#            team  points_per_game
# 8       croatia        54.854667
# 10      hungary        46.631250
# 11  netherlands        30.809273
# 12       sweden        30.457451
# 2       germany        29.468036
# 5       uruguay        27.774746
# 6         spain        25.600299
# 4        france        24.106575
# 7       england        23.357703
# 1         italy        20.796867

# %%
# Usando base_selecoes diretamente
base_selecoes['pontos_conquistados'] = base_selecoes['win'] * 3 + base_selecoes['draw']
base_selecoes['pontos_possiveis'] = base_selecoes['total_games'] * 3

# Calcular o aproveitamento em %
base_selecoes['aproveitamento'] = (base_selecoes['pontos_conquistados'] / base_selecoes['pontos_possiveis']) * 100

# Visualizar os melhores aproveitamentos
print(base_selecoes[['team', 'aproveitamento']].sort_values(by='aproveitamento', ascending=False).head(10))
# Out:
#            team  aproveitamento
# 0        brazil       72.222222
# 2       germany       70.238095
# 11  netherlands       63.030303
# 1         italy       62.650602
# 3     argentina       59.848485
# 4        france       59.817352
# 6         spain       54.726368
# 7       england       53.153153
# 8       croatia       52.222222
# 10      hungary       50.000000

# %%
plt.figure(figsize=(10, 6))
plt.scatter(base_selecoes['goals_against'], base_selecoes['goals_for'], c='blue')
for i, row in base_selecoes.iterrows():
    plt.text(row['goals_against'], row['goals_for'], row['team'], fontsize=8)
plt.xlabel('Gols Sofridos')
plt.ylabel('Gols Marcados')
plt.title('Gols Marcados vs Gols Sofridos por Seleção')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 5. Visualizações: desempenho por seleção
# Gráficos de dispersão, barras e histogramas para visualizar gols, taxa de vitória e aproveitamento das seleções.

# %%
base_selecoes['win_rate'] = base_selecoes['win'] / base_selecoes['total_games']
base_selecoes_sorted = base_selecoes.sort_values(by='win_rate', ascending=False)


plt.figure(figsize=(12, 6))
plt.bar(base_selecoes_sorted['team'], base_selecoes_sorted['win_rate'], color='green')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Taxa de Vitória')
plt.title('Taxa de Vitórias por Seleção')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
base_selecoes.columns
# Out:
# Index(['team', 'titles', 'finals', 'rank', 'points', 'goals_for',
#        'goals_against', 'win', 'draw', 'loss', 'total_games',
#        'points_per_game', 'pontos_conquistados', 'pontos_possiveis',
#        'aproveitamento', 'win_rate'],
#       dtype='str')

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=base_selecoes, x='total_games', y='win', scatter_kws={'s': 60}, line_kws={"color": "red"})
for i, row in base_selecoes.iterrows():
    plt.text(row['total_games'], row['win'], row['team'], fontsize=7, alpha=0.7)

plt.title('Relação entre Total de Jogos e Vitórias por Seleção')
plt.xlabel('Total de Jogos')
plt.ylabel('Total de Vitórias')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(base_selecoes['aproveitamento'], bins=15, kde=True, color='royalblue')
plt.title('Distribuição do Aproveitamento (%) das Seleções')
plt.xlabel('Aproveitamento (%)')
plt.ylabel('Número de Seleções')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(base_selecoes['win'], bins=15, kde=True, color='seagreen')
plt.title('Distribuição do Número de Vitórias das Seleções')
plt.xlabel('Número de Vitórias')
plt.ylabel('Número de Seleções')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Ordenar do maior para o menor
base_selecoes_sorted = base_selecoes.sort_values(by='win_rate', ascending=False)

# Converter para porcentagem
base_selecoes_sorted['win_rate_percent'] = base_selecoes_sorted['win_rate'] * 100

# Plotar
plt.figure(figsize=(14, 6))
sns.barplot(data=base_selecoes_sorted, x='team', y='win_rate_percent', hue='team', palette='viridis', legend=False)

plt.xticks(rotation=45, ha='right')
plt.ylabel('Taxa de Vitória (%)')
plt.xlabel('Seleção')
plt.title('Taxa de Vitórias por Seleção')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(base_selecoes['rank'], base_selecoes['win_rate'], c='green', edgecolor='black')

# Adicionar os nomes das seleções
for i, row in base_selecoes.iterrows():
    plt.text(row['rank'], row['win_rate'], row['team'], fontsize=8)

plt.xlabel('Ranking FIFA (quanto menor, melhor)')
plt.ylabel('Win Rate (Taxa de Vitórias)')
plt.title('Ranking FIFA vs Aproveitamento Histórico (Win Rate)')
plt.grid(True)
plt.gca().invert_xaxis()  # Ranking menor é melhor, inverte para mostrar melhor desempenho à esquerda
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Ranking FIFA vs. desempenho histórico
# Relação entre a posição no ranking FIFA e a taxa de vitórias histórica das seleções, incluindo a correlação entre as duas variáveis.

# %%
base_selecoes['tem_titulo'] = base_selecoes['titles'] > 0

plt.figure(figsize=(10, 6))
colors = base_selecoes['tem_titulo'].map({True: 'gold', False: 'gray'})

plt.scatter(base_selecoes['rank'], base_selecoes['win_rate'], c=colors, edgecolor='black', s=100, alpha=0.8)

# Anotar seleções
for i, row in base_selecoes.iterrows():
    plt.text(row['rank'], row['win_rate'], row['team'], fontsize=8)

plt.xlabel('Ranking FIFA (quanto menor, melhor)')
plt.ylabel('Win Rate (Taxa de Vitórias)')
plt.title('Ranking FIFA vs Aproveitamento Histórico')
plt.gca().invert_xaxis()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
correlacao = base_selecoes[['rank', 'win_rate']].corr().iloc[0,1]
print(f"Correlação entre Ranking FIFA e Win Rate: {correlacao:.2f}")
# Out:
# Correlação entre Ranking FIFA e Win Rate: -0.47

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=base_selecoes, x='rank', y='win_rate', scatter_kws={'s': 100, 'alpha': 0.7}, line_kws={'color': 'red'})
plt.xlabel('Ranking FIFA')
plt.ylabel('Win Rate')
plt.title('Tendência: Ranking FIFA vs Aproveitamento')
plt.gca().invert_xaxis()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Estatísticas descritivas e seleções sem títulos
# Resumo estatístico das principais variáveis e contagem de seleções que nunca venceram ou que chegaram à final sem título.

# %%
# Estatísticas descritivas básicas
desc_stats = base_selecoes[['titles', 'finals', 'rank', 'points']].describe()
print(desc_stats)
# Out:
#           titles     finals       rank       points
# count  13.000000  13.000000  12.000000    12.000000
# mean    1.692308   3.384615  11.000000  1684.949167
# std     1.797434   2.534379  10.135446    96.256446
# min     0.000000   1.000000   1.000000  1492.200000
# 25%     0.000000   1.000000   4.750000  1643.907500
# 50%     1.000000   2.000000   7.500000  1704.865000
# 75%     3.000000   6.000000  12.500000  1736.297500
# max     5.000000   8.000000  36.000000  1841.300000

# %%
# Contar quantas seleções não possuem títulos
nao_campeoes = base_selecoes[base_selecoes['titles'] == 0].shape[0]
print(f"Seleções que nunca venceram: {nao_campeoes}")
# Out:
# Seleções que nunca venceram: 5

# %%
# Quantas seleções chegaram à final ao menos uma vez, mas não venceram
vice_campeoes = base_selecoes[(base_selecoes['titles'] == 0) & (base_selecoes['finals'] > 0)].shape[0]
print(f"Seleções que chegaram à final mas nunca venceram: {vice_campeoes}")
# Out:
# Seleções que chegaram à final mas nunca venceram: 5

# %%
# Tabela de resumo com os principais dados
resumo_stats = pd.DataFrame({
    'Métrica': [
        'Seleções totais analisadas',
        'Seleções que nunca venceram',
        'Seleções que chegaram à final mas nunca venceram'
    ],
    'Valor': [
        base_selecoes.shape[0],
        nao_campeoes,
        vice_campeoes
    ]
})

print(resumo_stats)
# Out:
#                                             Métrica  Valor
# 0                        Seleções totais analisadas     13
# 1                       Seleções que nunca venceram      5
# 2  Seleções que chegaram à final mas nunca venceram      5

# %% [markdown]
# ## 8. Títulos, pontuação FIFA e correlações
# Comparação entre número de títulos, finais disputadas e pontuação FIFA, seguida de um mapa de calor de correlação entre as principais variáveis.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='titles', y='team', data=base_selecoes.sort_values('titles', ascending=False))
plt.title('Número de Títulos por Seleção')
plt.xlabel('Títulos')
plt.ylabel('Seleção')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='points', y='titles', data=base_selecoes, hue='team')
plt.title('Pontuação FIFA vs. Número de Títulos')
plt.xlabel('Pontuação FIFA (2022)')
plt.ylabel('Títulos')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='points', y='finals', data=base_selecoes, hue='team')
plt.title('Pontuação FIFA vs. Finais Disputadas')
plt.xlabel('Pontuação FIFA (2022)')
plt.ylabel('Finais Disputadas')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(base_selecoes[['titles', 'finals', 'rank', 'points']].corr(), annot=True, cmap='Blues')
plt.title('Correlação entre Variáveis')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Evolução histórica por década
# Análise temporal: campeões por década, participações das seleções e total de gols marcados nas Copas ao longo do tempo.

# %%
copa = dados_copa.copy()

# Criar uma nova coluna com a década
copa['decade'] = (copa['Year'] // 10) * 10

# Agrupar por década e campeão para contar quantos títulos cada time ganhou em cada década
campeoes_decada = copa.groupby(['decade', 'Champion']).size().reset_index(name='titulos')

# Melhorar visual dos nomes das seleções
campeoes_decada['Champion'] = campeoes_decada['Champion'].str.title()

# Criar o gráfico
plt.figure(figsize=(12, 6))
sns.barplot(data=campeoes_decada, x='decade', y='titulos', hue='Champion')
plt.title('Campeões da Copa do Mundo por Década')
plt.xlabel('Década')
plt.ylabel('Número de Títulos')
plt.legend(title='Seleção')
plt.tight_layout()
plt.show()

# %%
# Calcular total de jogos
desempenho_geral['jogos'] = desempenho_geral['win'] + desempenho_geral['draw'] + desempenho_geral['loss']

# Criar métricas derivadas
desempenho_geral['aproveitamento'] = (desempenho_geral['win'] / desempenho_geral['jogos']).round(2)
desempenho_geral['media_gols_marcados'] = (desempenho_geral['goals_for'] / desempenho_geral['jogos']).round(2)
desempenho_geral['media_gols_sofridos'] = (desempenho_geral['goals_against'] / desempenho_geral['jogos']).round(2)

# Reorganizar colunas (opcional)
colunas_ordenadas = [
    'team', 'jogos', 'win', 'draw', 'loss',
    'goals_for', 'goals_against',
    'aproveitamento', 'media_gols_marcados', 'media_gols_sofridos'
]
desempenho_geral = desempenho_geral[colunas_ordenadas]

# Visualizar
print(desempenho_geral.head())
# Out:
#         team  jogos  win  draw  loss  goals_for  goals_against  \
# 0    algeria     13    3     3     7         13             19
# 1     angola      3    0     2     1          1              2
# 2  argentina     88   47    17    24        152            101
# 3  australia     20    4     4    12         17             37
# 4    austria     29   12     4    13         43             47
#
#    aproveitamento  media_gols_marcados  media_gols_sofridos
# 0            0.23                 1.00                 1.46
# 1            0.00                 0.33                 0.67
# 2            0.53                 1.73                 1.15
# 3            0.20                 0.85                 1.85
# 4            0.41                 1.48                 1.62

# %%
match_results['decade'] = (match_results['Year'] // 10) * 10
participacoes_decada = pd.concat([
    match_results[['decade', 'home_team']].rename(columns={'home_team': 'team'}),
    match_results[['decade', 'away_team']].rename(columns={'away_team': 'team'})
])
participacoes_decada = participacoes_decada.drop_duplicates()
participacoes_por_decada = participacoes_decada.groupby(['decade', 'team']).size().reset_index(name='participacoes')

# Gráfico opcional (exemplo: últimas décadas)
sns.catplot(
    data=participacoes_por_decada[participacoes_por_decada['decade'] >= 1980],
    x='decade', y='participacoes', hue='team', kind='bar', height=5, aspect=2
)
plt.title('Participações por Seleção nas Copas por Década')
plt.show()
# Out:
# C:\Users\jhona\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
gols_decada = match_results.copy()
gols_decada['decade'] = (gols_decada['Year'] // 10) * 10
gols_agrupado = gols_decada.groupby('decade')[['home_score', 'away_score']].sum().reset_index()
gols_agrupado['total_gols'] = gols_agrupado['home_score'] + gols_agrupado['away_score']

plt.figure(figsize=(8,5))
sns.lineplot(data=gols_agrupado, x='decade', y='total_gols', marker='o')
plt.title('Total de Gols por Década nas Copas')
plt.xlabel('Década')
plt.ylabel('Total de Gols')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Top 10 seleções: aproveitamento e média de gols
# Ranking final das seleções com melhor aproveitamento, maior média de gols marcados e melhores defesas (menor média de gols sofridos).

# %%
# Médias de gols marcados/sofridos por seleção
# ('aproveitamento' já foi calculado antes a partir dos pontos conquistados)
base_selecoes['media_gols_marcados'] = (base_selecoes['goals_for'] / base_selecoes['total_games']).round(2)
base_selecoes['media_gols_sofridos'] = (base_selecoes['goals_against'] / base_selecoes['total_games']).round(2)

# Visualizar as 10 seleções com melhor aproveitamento
print(base_selecoes.sort_values('aproveitamento', ascending=False)[[
    'team', 'aproveitamento', 'win', 'draw', 'loss'
]].head(10))
# Out:
#            team  aproveitamento  win  draw  loss
# 0        brazil       72.222222   76    19    19
# 2       germany       70.238095   37     7    12
# 11  netherlands       63.030303   30    14    11
# 1         italy       62.650602   45    21    17
# 3     argentina       59.848485   47    17    24
# 4        france       59.817352   39    14    20
# 6         spain       54.726368   31    17    19
# 7       england       53.153153   32    22    20
# 8       croatia       52.222222   13     8     9
# 10      hungary       50.000000   15     3    14

# %%
# Garantir nomes capitalizados para visual
base_selecoes['team'] = base_selecoes['team'].str.title()

# 1. Top 10 - Aproveitamento
plt.figure(figsize=(10, 6))
sns.barplot(data=base_selecoes.sort_values('aproveitamento', ascending=False).head(10),
            x='aproveitamento', y='team')
plt.title('Top 10 Seleções com Melhor Aproveitamento')
plt.xlabel('Aproveitamento')
plt.ylabel('Seleção')
plt.tight_layout()
plt.show()

# 2. Top 10 - Média de Gols Marcados
plt.figure(figsize=(10, 6))
sns.barplot(data=base_selecoes.sort_values('media_gols_marcados', ascending=False).head(10),
            x='media_gols_marcados', y='team')
plt.title('Top 10 Seleções com Maior Média de Gols Marcados')
plt.xlabel('Média de Gols')
plt.ylabel('Seleção')
plt.tight_layout()
plt.show()

# 3. Top 10 - Menor Média de Gols Sofridos
plt.figure(figsize=(10, 6))
sns.barplot(data=base_selecoes[base_selecoes['total_games'] > 5].sort_values('media_gols_sofridos').head(10),
            x='media_gols_sofridos', y='team')
plt.title('Top 10 Melhores Defesas (Menor Média de Gols Sofridos)')
plt.xlabel('Média de Gols Sofridos')
plt.ylabel('Seleção')
plt.tight_layout()
plt.show()
